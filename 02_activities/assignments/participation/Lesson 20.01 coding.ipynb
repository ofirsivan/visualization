# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import PIL
import scipy
import requests

# %%
# fig, ax produce 2 different variabe → these are two objects
# the show is on the figure we can use plt 
# the fig is the entire plane of plotting

# %%
np.random.seed(613)
x=np.arange(50)
y=np.random.randint(0, 100,50)

fig,ax=plt.subplots(1,1,figsize=(5, 3))
fig.patch.set_facecolor("#e77e7e")

ax.patch.set_facecolor("#7ee793")
ax.tick_params(axis='both', colors='#7ee793')

# %%
# activity: choosing the right visualization
# lifespan/life expentency could be predicted
# visualiztion quality depends on a purpose
# second example: Washington Post
# there is no definition of active shooters
# active shooter can be involved in one or more event 
# differences create evocative vocabulary

# %%
#data feminism → rhetorical objects
# it can be factual without being  neutral
# we should be critical/reflexive about that

# %%
# Qualities of data visualiztion
#Three important qualities of data visualization:
# Is the visualization pleasing to look at? → Aesthetic
# Does the visualization accurately and honestly present data? → Substantive
# Can we understand what message the maker of the visualization is attempting to convey? → Perceptual

# %%
##question I havee about datatypes/versus data representation

# %%
#the best practices for data visualization

# %%
# The Data Visualisation Catalogue

# %%
#https://datavizcatalogue.com/#google_vignette

# %%
#Power BI
#https://www.microsoft.com/en-us/power-platform/products/power-bi

# %%
#comments  from lectures

# %% [markdown]
# Sammery of important materials from lecturs
#
#  communication: storyy telling, contextualization, advocacy → what is the massage  conveyed [perceptive] → the  purpose is un clear can it be merely descriptive?
#             -purpose: persuading, exploring, evaluating, comparing
#             * motivation / political use and reflexivity - Foucault [context- where and how, audiences: expertise [both in form/technique and  in field/content], age, accessibility, education ] intendend medium [web, poster, presentation]
#             * Aesthetic/pleased to look at: colour, size, use of images. [aesthtic]
#             * reepresentation of data [substentive, structure of data and what is captured with the visualiztion]
#             * decision making
#             * objectivity and pluralism - embracing multiple perspectives
#             * data feminism- data visualiztion as a rhetorical object D’Ignazio and Klein (2020)
#             * cognitive theory -  Gestalt principles (Wong, 2010): proximity, similarity, continuity, closure, enclosure, connection
#             * cognitive load: intrinsic [information complexity] Germane [ the audince famliarity with the information] and  Extraneous [complexity from presentation]
#             cognitive load: explanatory versus exploratory [self explained], familiarity/rareness of chart type, accurate and approximate interpretation [relational areas], concise vs. Detailed composition [number of visual elements]
#             * Sociologists Kennedy et al. (2016): conventions for data visualiztion: clean layout, two dimensions,gemomrtric shapes and lines, inclusion of data sources at the bottom image
