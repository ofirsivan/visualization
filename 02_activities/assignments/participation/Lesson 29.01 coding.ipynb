# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

from PIL import Image
import requests
from io import BytesIO

# %%
import plotly.graph_objects as go
from wordcloud import WordCloud

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(data=tips,       # choose our dataset
           x='total_bill',  # define our x variable
           y='tip')         # define our y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style ('whitegrid')
sns.lineplot(data=tips, x='total_bill', y='tip')
#add styles
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style ('dark')
sns.lineplot(data=tips, x='total_bill', y='tip')
#add styles
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style ('darkgrid')
sns.lineplot(data=tips, x='total_bill', y='tip')
#add styles
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style ('dark')
sns.lineplot(data=tips, x='total_bill', y='tip')
# add titles
tipgraph = sns.lineplot(data=tips,
                        x='total_bill',
                        y='tip')
tipgraph.set(title='Tips vs. Total Bill', 
            xlabel='Total Bill ($)', 
            ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
sns.set_style ('darkgrid')
sns.lineplot(data=tips, x='total_bill', y='tip')
# add titles
tipgraph = sns.lineplot(data=tips,
                        x='total_bill',
                        y='tip')
tipgraph.set(title='Tips vs. Total Bill', 
            xlabel='Total Bill ($)', 
            ylabel='Tip Amount ($)')

#design the plot

tipgraph = sns.lineplot(data=tips,
                      x='total_bill',
                      y='tip',
                      color = 'deeppink',
                      linestyle = '--',
                      linewidth = 3,
                      marker = '*',
                      markerfacecolor = 'indigo')

# %%
# the advantage of seaborn isthe ability to include multiple variables in our representation 

tipgraph=sns.scatterplot(data=tips, x="total_bill", y="tip", style= "time", hue="day")

# %%
# lets change from the defult color palet
tipgraph=sns.scatterplot(data=tips, x="total_bill", y="tip", style= "time", hue="day", palette=["purple","hotpink", "deepskyblue",'yellowgreen'])

# %%
# plot the connectio btween diferent types of variables- exploratory analysis
# it is based on the type of variables 

sns.pairplot (data=tips)

# %%
sns.pairplot (data=tips, hue= "day")
# we change the color based on the day

# %%
daysplot= sns.relplot(data=tips,x="total_bill", y= "tip", hue= "sex")

# %%
daysplot = sns.relplot(data=tips, x="total_bill", y="tip",hue="sex",col="day", kind="scatter",col_wrap=2)

# %%
daysplot = sns.relplot(data=tips, x="total_bill", y="tip",hue="sex",col="day", kind="scatter",col_wrap=4)

# %%
daysplot = sns.relplot(data=tips, x="total_bill", y="tip",hue="sex",col="day", kind="scatter",col_wrap=1)

# %%
daysplot = sns.relplot(data=tips, x="total_bill", y="tip",hue="sex",col="day", kind="scatter",col_wrap=3)

# %%
# look at the seaborn resources

# %%
# moving to plotly

# %%
# we will generate dataset and import our library

# %%
import plotly.graph_objects as go     # 'go' is 'graph objects’
x1 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
### from matplotlib_venn import venn2, venn2_circles, venn2_unweighted 
# how to create three-set Venn Diagaram

# %%
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# %%
graph= go.Figure()
graph.add_trace(go.Bar(x=x1, y=y1))

# %%
graph.update_layout(
    title="Pirate Scores",
    xaxis_title="Pirates",
    yaxis_title="Score")

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers',    # we want points for a scatter plot
    marker=dict(
        size=15,                            # point size
        color='gold',                    # point colour
        opacity=1,                          # point transparency/alpha
        line=dict(width=5, color='purple')  # point outline
    )))
graph.update_layout(
    title='Interactive Pirate Plot',
    xaxis_title='Pirates',
    yaxis_title='Scores',
    width=500, height=500)

# %%
# Making a word cloud

# %%
from wordcloud import WordCloud
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# ...

# %%
# join all our text from each row from our quote column into a string
text = " ".join(each for each in df.quote)
# generate our wordcloud image
wordcloud = WordCloud(background_color="green",
colormap = 'inferno').generate(text) #colormap= color pallet 
# use matplotlib syntax to put our image in a figure
fig, ax = plt.subplots(figsize=(7, 3))
ax.imshow(wordcloud,                  # remember 'imshow' from when we added pictures to our matplotlib axes
        interpolation='bilinear')   # this line helps smooth our image
ax.axis("off")
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %%
# the locatio and color of the word is created randomally

# %%
#Venn diagram

# %%
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# %%
# specify our sets A+B
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

# %%
diagram = venn2_unweighted([A, B], set_labels = ('Fruits', 'Pies'), set_colors=("blue", "red"), alpha=0.5)
plt.show()

# %%
diagram = venn2_unweighted([A, B], set_labels = ('Fruits', 'Pies'), set_colors=("blue", "red"), alpha=0.5)
diagram.get_label_by_id("10").set_text("\n".join(A - B)) # represent the blue region 
diagram.get_label_by_id("11").set_text("\n".join(A & B)) #represent the overlapping region
diagram.get_label_by_id("01").set_text("\n".join(B - A)) # represnt the red region
plt.show()

# %%
# remeber to use "\" before n to create the text appear vertically

# %%
#look a the Ven diagram documentation to betterunder the number
#https://github.com/konstantint/matplotlib-venn/blob/master/matplotlib_venn/_common.py#L12

# %%
#enf of coding session
